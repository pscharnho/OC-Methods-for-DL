# %% [markdown]
# Comparison of different h values (1 and 0.1) for ResAntiSymNets with given backprop learning rates of 0.1, 0.5 and 1. The stability with regard to the depth of the net is considered. For stable archtitectures a maximum depth of 120 layers is considered.
# The hidden layers have 8 neurons, gamma is set to 0.3 and the net is trained for 100 epochs. The results are averaged over 10 computations.

# %%
import torch
from Dataset.Dataset import makeMoonsDataset

dataset_size = 600
batch_size = 40
test_set_size = dataset_size * 0.2

train_loader, test_loader = makeMoonsDataset(dataset_size, batch_size)

# %% [markdown]
# ## Learning rate 0.1

# %% [markdown]
# ### h = 1

# %%
from Networks.ResNet import ResAntiSymNet
import numpy as np
import timeit

num_epochs = 100
num_features = 2
num_classes = 2
size_hidden = 8
gamma = 0.3
h = 1
lr = 0.1

max_layers = 40
train_results_per_layer = np.zeros(max_layers)
test_results_per_layer = np.zeros(max_layers)
basic_save_key = 'AntiSym_Comparison_results//AntiSymNet'

for num_hidden_layers in range(1,max_layers+1):
    tic = timeit.default_timer()
    num_layers = num_hidden_layers + 1
    print('Number of layers: '+str(num_layers))
    train_results_per_epoch = np.zeros(num_epochs)
    test_results_per_epoch = np.zeros(num_epochs)
    for i in range(10):
        net = ResAntiSymNet(features=num_features, classes=num_classes, num_layers=num_layers, gamma=gamma, h=h, bias=True, hidden_size=size_hidden)
        net.set_test_tracking(True)
        net.train(num_epochs, train_loader, test_loader, print_output=False)
        train_results_per_epoch += net.avg_correct_pred.numpy()
        test_results_per_epoch += net.test_results.numpy()
        
    train_results_per_epoch = train_results_per_epoch / 10
    test_results_per_epoch = test_results_per_epoch / 10
    train_save_key = basic_save_key+'_train_per_epoch_layers_'+str(num_layers)+'_h_'+str(h)+'_lr_'+str(lr)+'.csv'
    test_save_key = basic_save_key+'_test_per_epoch_layers_'+str(num_layers)+'_h_'+str(h)+'_lr_'+str(lr)+'.csv'
    
    np.savetxt(train_save_key, train_results_per_epoch, delimiter=',')
    np.savetxt(test_save_key, test_results_per_epoch, delimiter=',')
    
    train_results_per_layer[num_hidden_layers-1] = train_results_per_epoch.max()
    print('Max training accuracy: '+str(train_results_per_epoch.max()))
    test_results_per_layer[num_hidden_layers-1] = test_results_per_epoch.max()
    print('Max test accuracy: '+str(test_results_per_epoch.max()/test_set_size))
    
    toc = timeit.default_timer()
    print('Time elapsed: '+str(toc-tic))

train_save_key = basic_save_key+'_train_per_layer_h_'+str(h)+'_lr_'+str(lr)+'.csv'
test_save_key = basic_save_key+'_test_per_layer_h_'+str(h)+'_lr_'+str(lr)+'.csv'
np.savetxt(train_save_key, train_results_per_layer, delimiter=',')
np.savetxt(test_save_key, test_results_per_layer, delimiter=',')
# Out:
# Number of layers: 2
# Max training accuracy: 0.9474999904632568
# Max test accuracy: 0.9450000000000001
# Time elapsed: 12.789678981999941
# Number of layers: 3
# Max training accuracy: 0.9856249928474426
# Max test accuracy: 0.9791666666666666
# Time elapsed: 16.46214900300015
# Number of layers: 4
# Max training accuracy: 0.9989583313465118
# Max test accuracy: 0.9966666666666666
# Time elapsed: 22.298688333999962
# Number of layers: 5
# Max training accuracy: 0.9989583313465118
# Max test accuracy: 0.9975
# Time elapsed: 25.69672525599981
# Number of layers: 6
# Max training accuracy: 1.0
# Max test accuracy: 1.0
# Time elapsed: 28.811471888000142
# Number of layers: 7
# Max training accuracy: 0.9904166638851166
# Max test accuracy: 0.9891666666666666
# Time elapsed: 33.66371358399988
# Number of layers: 8
# Max training accuracy: 1.0
# Max test accuracy: 0.9991666666666668
# Time elapsed: 37.99518894700009
# Number of layers: 9
# Max training accuracy: 1.0
# Max test accuracy: 0.9983333333333333
# Time elapsed: 44.13530271700006
# Number of layers: 10
# Max training accuracy: 1.0
# Max test accuracy: 0.9991666666666668
# Time elapsed: 52.030954417999965
# Number of layers: 11
# Max training accuracy: 1.0
# Max test accuracy: 0.9991666666666668
# Time elapsed: 57.97349936699993
# Number of layers: 12
# Max training accuracy: 1.0
# Max test accuracy: 1.0
# Time elapsed: 57.997160353000254
# Number of layers: 13
# Max training accuracy: 1.0
# Max test accuracy: 0.9983333333333333
# Time elapsed: 62.3626230660002
# Number of layers: 14
# Max training accuracy: 1.0
# Max test accuracy: 0.9991666666666668
# Time elapsed: 62.98143228400022
# Number of layers: 15
# Max training accuracy: 0.990625
# Max test accuracy: 0.9908333333333333
# Time elapsed: 67.46802209599991
# Number of layers: 16
# Max training accuracy: 1.0
# Max test accuracy: 1.0
# Time elapsed: 70.90346432900014
# Number of layers: 17
# Max training accuracy: 0.9997916638851165
# Max test accuracy: 0.9991666666666668
# Time elapsed: 76.54248418800034
# Number of layers: 18
# Max training accuracy: 1.0
# Max test accuracy: 1.0
# Time elapsed: 82.29970667899988
# Number of layers: 19
# Max training accuracy: 1.0
# Max test accuracy: 1.0
# Time elapsed: 84.87181233599995
# Number of layers: 20
# Max training accuracy: 1.0
# Max test accuracy: 1.0
# Time elapsed: 89.30745967799976
# Number of layers: 21
# Max training accuracy: 1.0
# Max test accuracy: 1.0
# Time elapsed: 97.66976505599996
# Number of layers: 22
# Max training accuracy: 1.0
# Max test accuracy: 1.0
# Time elapsed: 98.70815581200031
# Number of layers: 23
# Max training accuracy: 1.0
# Max test accuracy: 0.9991666666666668
# Time elapsed: 100.48527177100004
# Number of layers: 24
# Max training accuracy: 1.0
# Max test accuracy: 1.0
# Time elapsed: 106.61353602899999
# Number of layers: 25
# Max training accuracy: 0.9916666686534882
# Max test accuracy: 0.9908333333333333
# Time elapsed: 116.69122896499994
# Number of layers: 26
# Max training accuracy: 1.0
# Max test accuracy: 0.9983333333333333
# Time elapsed: 114.44726604300013
# Number of layers: 27
# Max training accuracy: 0.9908333361148834
# Max test accuracy: 0.9908333333333333
# Time elapsed: 121.69212188099982
# Number of layers: 28
# Max training accuracy: 1.0
# Max test accuracy: 0.9983333333333333
# Time elapsed: 125.68200113900002
# Number of layers: 29
# Max training accuracy: 1.0
# Max test accuracy: 0.9991666666666668
# Time elapsed: 125.54167403500014
# Number of layers: 30
# Max training accuracy: 0.990625
# Max test accuracy: 0.9891666666666666
# Time elapsed: 132.14633950799998
# Number of layers: 31
# Max training accuracy: 0.940416669845581
# Max test accuracy: 0.9408333333333334
# Time elapsed: 133.8021340539999
# Number of layers: 32
# Max training accuracy: 0.9399999976158142
# Max test accuracy: 0.9416666666666667
# Time elapsed: 140.7406529130003
# Number of layers: 33
# Max training accuracy: 0.8264583289623261
# Max test accuracy: 0.8366666666666667
# Time elapsed: 145.203601274
# Number of layers: 34
# Max training accuracy: 0.818958330154419
# Max test accuracy: 0.8275
# Time elapsed: 146.2198423689997
# Number of layers: 35
# Max training accuracy: 0.8370833337306977
# Max test accuracy: 0.8450000000000001
# Time elapsed: 143.88568928800032
# Number of layers: 36
# Max training accuracy: 0.8293749988079071
# Max test accuracy: 0.8358333333333333
# Time elapsed: 150.14144980400033
# Number of layers: 37
# Max training accuracy: 0.6877083361148835
# Max test accuracy: 0.6991666666666667
# Time elapsed: 151.7786509309999
# Number of layers: 38
# Max training accuracy: 0.8366666674613953
# Max test accuracy: 0.8441666666666666
# Time elapsed: 160.2307341959995
# Number of layers: 39
# Max training accuracy: 0.8150000035762787
# Max test accuracy: 0.8233333333333334
# Time elapsed: 177.75609722299941
# Number of layers: 40
# Max training accuracy: 0.5870833337306977
# Max test accuracy: 0.6041666666666666
# Time elapsed: 184.6048217460002
# Number of layers: 41
# Max training accuracy: 0.5462500035762787
# Max test accuracy: 0.565
# Time elapsed: 177.88541118299963

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
layers = np.arange(2,max_layers+2,1)
ax.plot(layers, train_results_per_layer, label='train')
ax.plot(layers, test_results_per_layer/test_set_size, label='test')
ax.set_ylim(0,1.1)
ax.set_xlabel('Number of Layers')
ax.set_ylabel('Average Accuracy')
ax.legend(loc='best')

# %% [markdown]
# ### h =  0.1

# %%
from Networks.ResNet import ResAntiSymNet
import numpy as np
import timeit

num_epochs = 100
num_features = 2
num_classes = 2
size_hidden = 8
gamma = 0.3
h = 0.1
lr = 0.1

max_layers = 120
train_results_per_layer = np.zeros(max_layers)
test_results_per_layer = np.zeros(max_layers)
basic_save_key = 'AntiSym_Comparison_results//AntiSymNet'

for num_hidden_layers in range(1,max_layers+1):
    tic = timeit.default_timer()
    num_layers = num_hidden_layers + 1
    print('Number of layers: '+str(num_layers))
    train_results_per_epoch = np.zeros(num_epochs)
    test_results_per_epoch = np.zeros(num_epochs)
    for i in range(10):
        net = ResAntiSymNet(features=num_features, classes=num_classes, num_layers=num_layers, gamma=gamma, h=h, bias=True, hidden_size=size_hidden)
        net.set_test_tracking(True)
        net.train(num_epochs, train_loader, test_loader, print_output=False)
        train_results_per_epoch += net.avg_correct_pred.numpy()
        test_results_per_epoch += net.test_results.numpy()
        
    train_results_per_epoch = train_results_per_epoch / 10
    test_results_per_epoch = test_results_per_epoch / 10
    train_save_key = basic_save_key+'_train_per_epoch_layers_'+str(num_layers)+'_h_'+str(h)+'_lr_'+str(lr)+'.csv'
    test_save_key = basic_save_key+'_test_per_epoch_layers_'+str(num_layers)+'_h_'+str(h)+'_lr_'+str(lr)+'.csv'
    
    np.savetxt(train_save_key, train_results_per_epoch, delimiter=',')
    np.savetxt(test_save_key, test_results_per_epoch, delimiter=',')
    
    train_results_per_layer[num_hidden_layers-1] = train_results_per_epoch.max()
    print('Max training accuracy: '+str(train_results_per_epoch.max()))
    test_results_per_layer[num_hidden_layers-1] = test_results_per_epoch.max()
    print('Max test accuracy: '+str(test_results_per_epoch.max()/test_set_size))
    
    toc = timeit.default_timer()
    print('Time elapsed: '+str(toc-tic))

train_save_key = basic_save_key+'_train_per_layer_h_'+str(h)+'_lr_'+str(lr)+'.csv'
test_save_key = basic_save_key+'_test_per_layer_h_'+str(h)+'_lr_'+str(lr)+'.csv'
np.savetxt(train_save_key, train_results_per_layer, delimiter=',')
np.savetxt(test_save_key, test_results_per_layer, delimiter=',')
# Out:
# Number of layers: 2
# Max training accuracy: 0.940416669845581
# Max test accuracy: 0.955
# Time elapsed: 11.628685269999991
# Number of layers: 3
# Max training accuracy: 0.9229166686534882
# Max test accuracy: 0.9450000000000001
# Time elapsed: 14.960609403000007
# Number of layers: 4
# Max training accuracy: 0.9445833265781403
# Max test accuracy: 0.95
# Time elapsed: 18.329642236999987
# Number of layers: 5
# Max training accuracy: 0.9210416734218597
# Max test accuracy: 0.9283333333333333
# Time elapsed: 22.024457772999995
# Number of layers: 6
# Max training accuracy: 0.926458328962326
# Max test accuracy: 0.94
# Time elapsed: 24.795526373
# Number of layers: 7
# Max training accuracy: 0.9287499904632568
# Max test accuracy: 0.9366666666666668
# Time elapsed: 29.42907770100001
# Number of layers: 8
# Max training accuracy: 0.9362499952316284
# Max test accuracy: 0.94
# Time elapsed: 33.696739648999994
# Number of layers: 9
# Max training accuracy: 0.9208333313465118
# Max test accuracy: 0.9283333333333333
# Time elapsed: 38.653537838999995
# Number of layers: 10
# Max training accuracy: 0.9291666746139526
# Max test accuracy: 0.9358333333333333
# Time elapsed: 38.49169696199999
# Number of layers: 11
# Max training accuracy: 0.9343749940395355
# Max test accuracy: 0.9408333333333334
# Time elapsed: 42.408528811
# Number of layers: 12
# Max training accuracy: 0.9375000059604645
# Max test accuracy: 0.9408333333333334
# Time elapsed: 48.674559146000036
# Number of layers: 13
# Max training accuracy: 0.9429166615009308
# Max test accuracy: 0.9566666666666667
# Time elapsed: 53.017350943999986
# Number of layers: 14
# Max training accuracy: 0.9431250035762787
# Max test accuracy: 0.9575
# Time elapsed: 53.721814804000076
# Number of layers: 15
# Max training accuracy: 0.9254166662693024
# Max test accuracy: 0.9333333333333333
# Time elapsed: 60.64417378799999
# Number of layers: 16
# Max training accuracy: 0.959375
# Max test accuracy: 0.9716666666666666
# Time elapsed: 58.44810755200001
# Number of layers: 17
# Max training accuracy: 0.9587500035762787
# Max test accuracy: 0.9633333333333333
# Time elapsed: 66.8953957
# Number of layers: 18
# Max training accuracy: 0.943958330154419
# Max test accuracy: 0.9466666666666667
# Time elapsed: 67.04302446100007
# Number of layers: 19
# Max training accuracy: 0.9299999952316285
# Max test accuracy: 0.9358333333333333
# Time elapsed: 72.94822167300003
# Number of layers: 20
# Max training accuracy: 0.9354166805744171
# Max test accuracy: 0.9475
# Time elapsed: 76.85616754599994
# Number of layers: 21
# Max training accuracy: 0.9285416662693023
# Max test accuracy: 0.9358333333333333
# Time elapsed: 80.828388453
# Number of layers: 22
# Max training accuracy: 0.932708328962326
# Max test accuracy: 0.9441666666666666
# Time elapsed: 81.23192526499986
# Number of layers: 23
# Max training accuracy: 0.9352083325386047
# Max test accuracy: 0.9458333333333333
# Time elapsed: 86.15025867300005
# Number of layers: 24
# Max training accuracy: 0.9418749928474426
# Max test accuracy: 0.9391666666666667
# Time elapsed: 88.071327376
# Number of layers: 25
# Max training accuracy: 0.9377083420753479
# Max test accuracy: 0.9433333333333334
# Time elapsed: 93.33065287199997
# Number of layers: 26
# Max training accuracy: 0.9637499988079071
# Max test accuracy: 0.9725
# Time elapsed: 96.52796877800006
# Number of layers: 27
# Max training accuracy: 0.9539583325386047
# Max test accuracy: 0.9608333333333333
# Time elapsed: 100.50080501299999
# Number of layers: 28
# Max training accuracy: 0.9414583325386048
# Max test accuracy: 0.955
# Time elapsed: 102.95860201400001
# Number of layers: 29
# Max training accuracy: 0.9331249952316284
# Max test accuracy: 0.9416666666666667
# Time elapsed: 105.94558353599996
# Number of layers: 30
# Max training accuracy: 0.9627083301544189
# Max test accuracy: 0.9658333333333334
# Time elapsed: 109.06207024900004
# Number of layers: 31
# Max training accuracy: 0.9820833265781402
# Max test accuracy: 0.9841666666666666
# Time elapsed: 116.19427680499984
# Number of layers: 32
# Max training accuracy: 0.9445833325386047
# Max test accuracy: 0.9508333333333333
# Time elapsed: 110.85007906200008
# Number of layers: 33
# Max training accuracy: 0.9435416519641876
# Max test accuracy: 0.9533333333333334
# Time elapsed: 122.74245930799998
# Number of layers: 34
# Max training accuracy: 0.9522916674613953
# Max test accuracy: 0.9641666666666667
# Time elapsed: 123.708737724
# Number of layers: 35
# Max training accuracy: 0.9539583206176758
# Max test accuracy: 0.9558333333333333
# Time elapsed: 124.7754761189999
# Number of layers: 36
# Max training accuracy: 0.9399999976158142
# Max test accuracy: 0.9483333333333334
# Time elapsed: 133.43835641799978
# Number of layers: 37
# Max training accuracy: 0.9322916626930237
# Max test accuracy: 0.9299999999999999
# Time elapsed: 132.9082774379999
# Number of layers: 38
# Max training accuracy: 0.9520833313465118
# Max test accuracy: 0.9625
# Time elapsed: 136.96099494600003
# Number of layers: 39
# Max training accuracy: 0.95625
# Max test accuracy: 0.9616666666666667
# Time elapsed: 139.14721957200027
# Number of layers: 40
# Max training accuracy: 0.9591666638851166
# Max test accuracy: 0.9608333333333333
# Time elapsed: 143.6257962740001
# Number of layers: 41
# Max training accuracy: 0.9589583396911621
# Max test accuracy: 0.9616666666666667
# Time elapsed: 147.88158249199978
# Number of layers: 42
# Max training accuracy: 0.9489583194255828
# Max test accuracy: 0.9566666666666667
# Time elapsed: 151.21110700999998
# Number of layers: 43
# Max training accuracy: 0.9458333313465118
# Max test accuracy: 0.9575
# Time elapsed: 153.97183844999972
# Number of layers: 44
# Max training accuracy: 0.9616666555404663
# Max test accuracy: 0.9716666666666666
# Time elapsed: 159.0852983990003
# Number of layers: 45
# Max training accuracy: 0.9745833218097687
# Max test accuracy: 0.9833333333333333
# Time elapsed: 161.20173576299976
# Number of layers: 46
# Max training accuracy: 0.9572916746139526
# Max test accuracy: 0.9633333333333333
# Time elapsed: 166.10677258900023
# Number of layers: 47
# Max training accuracy: 0.9537500023841858
# Max test accuracy: 0.9608333333333333
# Time elapsed: 168.9513080679999
# Number of layers: 48
# Max training accuracy: 0.9356249928474426
# Max test accuracy: 0.9583333333333334
# Time elapsed: 169.5284848909996
# Number of layers: 49
# Max training accuracy: 0.9456249892711639
# Max test accuracy: 0.9575
# Time elapsed: 176.40269118800006
# Number of layers: 50
# Max training accuracy: 0.95625
# Max test accuracy: 0.9625
# Time elapsed: 176.96777740500056
# Number of layers: 51
# Max training accuracy: 0.9529166638851165
# Max test accuracy: 0.9583333333333334
# Time elapsed: 181.88168530199982
# Number of layers: 52
# Max training accuracy: 0.9689583361148835
# Max test accuracy: 0.9758333333333333
# Time elapsed: 184.07610964200012
# Number of layers: 53
# Max training accuracy: 0.9539583325386047
# Max test accuracy: 0.965
# Time elapsed: 188.853444589
# Number of layers: 54
# Max training accuracy: 0.9410416662693024
# Max test accuracy: 0.9516666666666667
# Time elapsed: 190.77266577299997
# Number of layers: 55
# Max training accuracy: 0.9656249940395355
# Max test accuracy: 0.9716666666666666
# Time elapsed: 197.64772129099947
# Number of layers: 56
# Max training accuracy: 0.9491666674613952
# Max test accuracy: 0.955
# Time elapsed: 196.45266620500024
# Number of layers: 57
# Max training accuracy: 0.9552083253860474
# Max test accuracy: 0.9633333333333333
# Time elapsed: 199.68249412000023
# Number of layers: 58
# Max training accuracy: 0.9643750011920929
# Max test accuracy: 0.9683333333333334
# Time elapsed: 207.11003170700042
# Number of layers: 59
# Max training accuracy: 0.9341666638851166
# Max test accuracy: 0.9466666666666667
# Time elapsed: 208.2817393819996
# Number of layers: 60
# Max training accuracy: 0.943958330154419
# Max test accuracy: 0.9525
# Time elapsed: 213.32367455700023
# Number of layers: 61
# Max training accuracy: 0.9520833313465118
# Max test accuracy: 0.9633333333333333
# Time elapsed: 213.84854820200053
# Number of layers: 62
# Max training accuracy: 0.9643750011920929
# Max test accuracy: 0.9758333333333333
# Time elapsed: 221.6414672810006
# Number of layers: 63
# Max training accuracy: 0.9449999928474426
# Max test accuracy: 0.9566666666666667
# Time elapsed: 227.17016447800052
# Number of layers: 64
# Max training accuracy: 0.9758333206176758
# Max test accuracy: 0.9825
# Time elapsed: 224.68142282600002
# Number of layers: 65
# Max training accuracy: 0.9599999964237214
# Max test accuracy: 0.9683333333333334
# Time elapsed: 233.68502481799987
# Number of layers: 66
# Max training accuracy: 0.9558333396911621
# Max test accuracy: 0.9674999999999999
# Time elapsed: 231.817409753
# Number of layers: 67
# Max training accuracy: 0.9625
# Max test accuracy: 0.9666666666666667
# Time elapsed: 236.2705853870002
# Number of layers: 68
# Max training accuracy: 0.9316666543483734
# Max test accuracy: 0.94
# Time elapsed: 235.1397873450005
# Number of layers: 69
# Max training accuracy: 0.9393749952316284
# Max test accuracy: 0.9491666666666667
# Time elapsed: 243.93588946099953
# Number of layers: 70
# Max training accuracy: 0.970208328962326
# Max test accuracy: 0.9741666666666667
# Time elapsed: 245.96755173400015
# Number of layers: 71
# Max training accuracy: 0.9562499940395355
# Max test accuracy: 0.9633333333333333
# Time elapsed: 251.83261913800015
# Number of layers: 72
# Max training accuracy: 0.9585416615009308
# Max test accuracy: 0.9625
# Time elapsed: 251.7219314949998
# Number of layers: 73
# Max training accuracy: 0.9447916686534882
# Max test accuracy: 0.9491666666666667
# Time elapsed: 255.99749294700086
# Number of layers: 74
# Max training accuracy: 0.9591666698455811
# Max test accuracy: 0.9758333333333333
# Time elapsed: 262.55268666399934
# Number of layers: 75
# Max training accuracy: 0.9316666603088379
# Max test accuracy: 0.9325
# Time elapsed: 266.5499626799992
# Number of layers: 76
# Max training accuracy: 0.964166659116745
# Max test accuracy: 0.9716666666666666
# Time elapsed: 267.45401303200015
# Number of layers: 77
# Max training accuracy: 0.9693750023841858
# Max test accuracy: 0.9725
# Time elapsed: 268.9482905570003
# Number of layers: 78
# Max training accuracy: 0.9556249976158142
# Max test accuracy: 0.9608333333333333
# Time elapsed: 273.71390450500076
# Number of layers: 79
# Max training accuracy: 0.9741666555404663
# Max test accuracy: 0.9825
# Time elapsed: 281.26134984999953
# Number of layers: 80
# Max training accuracy: 0.9558333218097687
# Max test accuracy: 0.9641666666666667
# Time elapsed: 281.6825851070007
# Number of layers: 81
# Max training accuracy: 0.9443750023841858
# Max test accuracy: 0.9533333333333334
# Time elapsed: 287.7709215800005
# Number of layers: 82
# Max training accuracy: 0.9770833373069763
# Max test accuracy: 0.9825
# Time elapsed: 288.3404934530008
# Number of layers: 83
# Max training accuracy: 0.9610416531562805
# Max test accuracy: 0.9691666666666666
# Time elapsed: 292.8539756090013
# Number of layers: 84
# Max training accuracy: 0.9358333230018616
# Max test accuracy: 0.9408333333333334
# Time elapsed: 294.8310821089999
# Number of layers: 85
# Max training accuracy: 0.9689583301544189
# Max test accuracy: 0.9716666666666666
# Time elapsed: 302.378126489999
# Number of layers: 86
# Max training accuracy: 0.970208328962326
# Max test accuracy: 0.9791666666666666
# Time elapsed: 303.352288991
# Number of layers: 87
# Max training accuracy: 0.9627083241939545
# Max test accuracy: 0.9708333333333333
# Time elapsed: 301.16030641900034
# Number of layers: 88
# Max training accuracy: 0.9572916567325592
# Max test accuracy: 0.9633333333333333
# Time elapsed: 306.22613750299934
# Number of layers: 89
# Max training accuracy: 0.9570833325386048
# Max test accuracy: 0.965
# Time elapsed: 315.77566529199976
# Number of layers: 90
# Max training accuracy: 0.9495833337306976
# Max test accuracy: 0.9591666666666666
# Time elapsed: 315.8843512000003
# Number of layers: 91
# Max training accuracy: 0.9727083325386048
# Max test accuracy: 0.98
# Time elapsed: 316.10622666200106
# Number of layers: 92
# Max training accuracy: 0.9472916603088379
# Max test accuracy: 0.9541666666666667
# Time elapsed: 331.1514584810011
# Number of layers: 93
# Max training accuracy: 0.9770833253860474
# Max test accuracy: 0.9841666666666666
# Time elapsed: 325.98184867099917
# Number of layers: 94
# Max training accuracy: 0.9631250023841857
# Max test accuracy: 0.9725
# Time elapsed: 331.6532540799999
# Number of layers: 95
# Max training accuracy: 0.9497916638851166
# Max test accuracy: 0.9525
# Time elapsed: 334.3661037410002
# Number of layers: 96
# Max training accuracy: 0.9533333241939544
# Max test accuracy: 0.965
# Time elapsed: 337.9216146300005
# Number of layers: 97
# Max training accuracy: 0.9541666567325592
# Max test accuracy: 0.9658333333333334
# Time elapsed: 334.56876583300254
# Number of layers: 98
# Max training accuracy: 0.9377083361148835
# Max test accuracy: 0.9416666666666667
# Time elapsed: 341.52659573300116
# Number of layers: 99
# Max training accuracy: 0.956458330154419
# Max test accuracy: 0.9600000000000001
# Time elapsed: 348.8388315089978
# Number of layers: 100
# Max training accuracy: 0.9464583337306977
# Max test accuracy: 0.9516666666666667
# Time elapsed: 346.89844970800186
# Number of layers: 101
# Max training accuracy: 0.9777083218097686
# Max test accuracy: 0.9858333333333333
# Time elapsed: 352.53626513400013
# Number of layers: 102
# Max training accuracy: 0.9633333325386048
# Max test accuracy: 0.9725
# Time elapsed: 356.47908818699943
# Number of layers: 103
# Max training accuracy: 0.9304166615009308
# Max test accuracy: 0.9450000000000001
# Time elapsed: 359.5727004210021
# Number of layers: 104
# Max training accuracy: 0.9397916674613953
# Max test accuracy: 0.9491666666666667
# Time elapsed: 361.8862167099978
# Number of layers: 105
# Max training accuracy: 0.9504166662693023
# Max test accuracy: 0.9575
# Time elapsed: 364.6247943769995
# Number of layers: 106
# Max training accuracy: 0.9735416650772095
# Max test accuracy: 0.9816666666666667
# Time elapsed: 370.83505268099907
# Number of layers: 107
# Max training accuracy: 0.9431250035762787
# Max test accuracy: 0.9466666666666667
# Time elapsed: 375.58876416699786
# Number of layers: 108
# Max training accuracy: 0.9637499988079071
# Max test accuracy: 0.9741666666666667
# Time elapsed: 378.6039586450024
# Number of layers: 109
# Max training accuracy: 0.9714583218097687
# Max test accuracy: 0.975
# Time elapsed: 382.57079584200255
# Number of layers: 110
# Max training accuracy: 0.9816666603088379
# Max test accuracy: 0.9891666666666666
# Time elapsed: 392.05546256800153
# Number of layers: 111
# Max training accuracy: 0.9612499892711639
# Max test accuracy: 0.9700000000000001
# Time elapsed: 387.0121085969986
# Number of layers: 112
# Max training accuracy: 0.9495833277702331
# Max test accuracy: 0.9566666666666667
# Time elapsed: 387.39702782899985
# Number of layers: 113
# Max training accuracy: 0.9685416638851165
# Max test accuracy: 0.9791666666666666
# Time elapsed: 398.58878781399835
# Number of layers: 114
# Max training accuracy: 0.9610416650772095
# Max test accuracy: 0.9716666666666666
# Time elapsed: 392.67270083199764
# Number of layers: 115
# Max training accuracy: 0.9408333361148834
# Max test accuracy: 0.9416666666666667
# Time elapsed: 400.4344038390009
# Number of layers: 116
# Max training accuracy: 0.9539583325386047
# Max test accuracy: 0.965
# Time elapsed: 403.36959829600164
# Number of layers: 117
# Max training accuracy: 0.9335416555404663
# Max test accuracy: 0.9441666666666666
# Time elapsed: 409.7208005709981
# Number of layers: 118
# Max training accuracy: 0.9520833313465118
# Max test accuracy: 0.9600000000000001
# Time elapsed: 410.06581206499686
# Number of layers: 119
# Max training accuracy: 0.9791666626930237
# Max test accuracy: 0.9841666666666666
# Time elapsed: 414.80154957099876
# Number of layers: 120
# Max training accuracy: 0.9556249856948853
# Max test accuracy: 0.9683333333333334
# Time elapsed: 415.23337027699745
# Number of layers: 121
# Max training accuracy: 0.9281249940395355
# Max test accuracy: 0.9383333333333332
# Time elapsed: 421.3018950170008

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
layers = np.arange(2,max_layers+2,1)
ax.plot(layers, train_results_per_layer, label='train')
ax.plot(layers, test_results_per_layer/test_set_size, label='test')
ax.set_ylim(0,1.1)
ax.set_xlabel('Number of Layers')
ax.set_ylabel('Average Accuracy')
ax.legend(loc='best')

# %% [markdown]
# ## Learning rate 0.5

# %% [markdown]
# ### h = 1

# %%
from Networks.ResNet import ResAntiSymNet
import numpy as np
import timeit

num_epochs = 100
num_features = 2
num_classes = 2
size_hidden = 8
gamma = 0.3
h = 1
lr = 0.5

max_layers = 20
train_results_per_layer = np.zeros(max_layers)
test_results_per_layer = np.zeros(max_layers)
basic_save_key = 'AntiSym_Comparison_results//AntiSymNet'

for num_hidden_layers in range(1,max_layers+1):
    tic = timeit.default_timer()
    num_layers = num_hidden_layers + 1
    print('Number of layers: '+str(num_layers))
    train_results_per_epoch = np.zeros(num_epochs)
    test_results_per_epoch = np.zeros(num_epochs)
    for i in range(10):
        net = ResAntiSymNet(features=num_features, classes=num_classes, num_layers=num_layers, gamma=gamma, h=h, bias=True, hidden_size=size_hidden)
        net.set_test_tracking(True)
        net.train(num_epochs, train_loader, test_loader, print_output=False)
        train_results_per_epoch += net.avg_correct_pred.numpy()
        test_results_per_epoch += net.test_results.numpy()
        del net
        
    train_results_per_epoch = train_results_per_epoch / 10
    test_results_per_epoch = test_results_per_epoch / 10
    train_save_key = basic_save_key+'_train_per_epoch_layers_'+str(num_layers)+'_h_'+str(h)+'_lr_'+str(lr)+'.csv'
    test_save_key = basic_save_key+'_test_per_epoch_layers_'+str(num_layers)+'_h_'+str(h)+'_lr_'+str(lr)+'.csv'
    
    np.savetxt(train_save_key, train_results_per_epoch, delimiter=',')
    np.savetxt(test_save_key, test_results_per_epoch, delimiter=',')
    
    train_results_per_layer[num_hidden_layers-1] = train_results_per_epoch.max()
    print('Max training accuracy: '+str(train_results_per_epoch.max()))
    test_results_per_layer[num_hidden_layers-1] = test_results_per_epoch.max()
    print('Max test accuracy: '+str(test_results_per_epoch.max()/test_set_size))
    
    toc = timeit.default_timer()
    print('Time elapsed: '+str(toc-tic))

train_save_key = basic_save_key+'_train_per_layer_h_'+str(h)+'_lr_'+str(lr)+'.csv'
test_save_key = basic_save_key+'_test_per_layer_h_'+str(h)+'_lr_'+str(lr)+'.csv'
np.savetxt(train_save_key, train_results_per_layer, delimiter=',')
np.savetxt(test_save_key, test_results_per_layer, delimiter=',')
# Out:
# Number of layers: 2
# Max training accuracy: 0.9662499904632569
# Max test accuracy: 0.9600000000000001
# Time elapsed: 12.112743869000042
# Number of layers: 3
# Max training accuracy: 0.9985416471958161
# Max test accuracy: 0.9975
# Time elapsed: 16.315213189000133
# Number of layers: 4
# Max training accuracy: 0.9985416531562805
# Max test accuracy: 0.9975
# Time elapsed: 20.84354746200006
# Number of layers: 5
# Max training accuracy: 0.9981249868869781
# Max test accuracy: 0.9975
# Time elapsed: 24.1426120849992
# Number of layers: 6
# Max training accuracy: 0.9983333230018616
# Max test accuracy: 0.9983333333333333
# Time elapsed: 30.043436734000352
# Number of layers: 7
# Max training accuracy: 0.9991666555404664
# Max test accuracy: 0.9958333333333333
# Time elapsed: 33.38494030799848
# Number of layers: 8
# Max training accuracy: 0.9891666531562805
# Max test accuracy: 0.9875
# Time elapsed: 38.8770654789987
# Number of layers: 9
# Max training accuracy: 0.9931249916553497
# Max test accuracy: 0.9933333333333334
# Time elapsed: 44.380669526999554
# Number of layers: 10
# Max training accuracy: 0.9879166483879089
# Max test accuracy: 0.9858333333333333
# Time elapsed: 45.3374343029991
# Number of layers: 11
# Max training accuracy: 0.9568749904632569
# Max test accuracy: 0.9333333333333333
# Time elapsed: 52.599229841000124
# Number of layers: 12
# Max training accuracy: 0.989166659116745
# Max test accuracy: 0.985
# Time elapsed: 55.265721899999335
# Number of layers: 13
# Max training accuracy: 0.976666659116745
# Max test accuracy: 0.9725
# Time elapsed: 57.78252588800024
# Number of layers: 14
# Max training accuracy: 0.9639583230018616
# Max test accuracy: 0.9575
# Time elapsed: 64.43589614399934
# Number of layers: 15
# Max training accuracy: 0.956458330154419
# Max test accuracy: 0.9516666666666667
# Time elapsed: 64.75633420200029
# Number of layers: 16
# Max training accuracy: 0.9349999964237213
# Max test accuracy: 0.8983333333333333
# Time elapsed: 69.47652047500014
# Number of layers: 17
# Max training accuracy: 0.9535416603088379
# Max test accuracy: 0.9491666666666667
# Time elapsed: 71.95118058200023
# Number of layers: 18
# Max training accuracy: 0.9464583277702332
# Max test accuracy: 0.9291666666666667
# Time elapsed: 76.8870962609999
# Number of layers: 19
# Max training accuracy: 0.9185416579246521
# Max test accuracy: 0.9091666666666666
# Time elapsed: 85.31754751900007
# Number of layers: 20
# Max training accuracy: 0.8566666543483734
# Max test accuracy: 0.85
# Time elapsed: 82.93505771899981
# Number of layers: 21
# Max training accuracy: 0.7189583241939544
# Max test accuracy: 0.7033333333333334
# Time elapsed: 91.47647318300005

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
layers = np.arange(2,max_layers+2,1)
ax.plot(layers, train_results_per_layer, label='train')
ax.plot(layers, test_results_per_layer/test_set_size, label='test')
ax.set_ylim(0,1.1)
ax.set_xlabel('Number of Layers')
ax.set_ylabel('Average Accuracy')
ax.legend(loc='best')
